# %%
import requests
from bs4 import BeautifulSoup
import os

if not os.path.exists('ptt_movie'):
    os.mkdir('ptt_movie')

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36'}
url = 'https://www.ptt.cc/bbs/movie/index.html'

for t in range(0, 1):
    res = requests.get(url, headers=headers)
    soup = BeautifulSoup(res.text, 'html.parser')
    
    # url and title in one page
    title_soup_list = soup.select('div.title')
    for title_soup in title_soup_list:
    #     print('=============')
    #     print(title_soup)
        title_info = title_soup.select('a')[0]
        title_name = title_info.text
        
        # Extract article content
        article_url = 'https://www.ptt.cc' + title_info['href']
        res_article = requests.get(article_url, headers=headers)
        soup_article = BeautifulSoup(res_article.text, 'html.parser')
        article_content = soup_article.select('div[id="main-content"]')[0].text.split('※ 發信站')[0]
#         print(article_content)
        try:
            with open('./ptt_movie/{}.txt'.format(title_name), 'w', encoding='utf-8') as f:
                f.write(article_content)
        except FileNotFoundError:
            title_name = title_name.replace('/', '')
            with open('./ptt_movie/{}.txt'.format(title_name), 'w', encoding='utf-8') as f:
                f.write(article_content)
        
        print(title_name)
        print(article_url)
        print('=====================')
    
    # get last-page-url
    url = 'https://www.ptt.cc' + soup.select('a.wide.btn')[1]['href']
# Out:
# [問片] 動物動畫的電影
# https://www.ptt.cc/bbs/movie/M.1587879591.A.68F.html
# =====================
# [討論] 挑戰取個比刺激1995更好的名？
# https://www.ptt.cc/bbs/movie/M.1587880283.A.215.html
# =====================
# [極好雷] 大隻佬
# https://www.ptt.cc/bbs/movie/M.1587880533.A.90D.html
# =====================
# [公告] 板規 20200301 (增加14.1)
# https://www.ptt.cc/bbs/movie/M.1559611458.A.DCA.html
# =====================
# [公告] 板規新增每日發文上限規定
# https://www.ptt.cc/bbs/movie/M.1565855832.A.0A7.html
# =====================
# [公告] 關於跑步哥
# https://www.ptt.cc/bbs/movie/M.1578684521.A.1B8.html
# =====================
# [板規] 串流平台情報規範
# https://www.ptt.cc/bbs/movie/M.1584946598.A.41F.html
# =====================

# %%
#test for article
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36'}
url = 'https://www.ptt.cc/bbs/movie/M.1587746659.A.C6B.html'

res = requests.get(url, headers=headers)
soup = BeautifulSoup(res.text, 'html.parser')

# %%
soup.select('div[id="main-content"]')[0]
# Out:
# <div class="bbs-screen bbs-content" id="main-content"><div class="article-metaline"><span class="article-meta-tag">作者</span><span class="article-meta-value">plutox (網路上的芳鄰)</span></div><div class="article-metaline-right"><span class="article-meta-tag">看板</span><span class="article-meta-value">movie</span></div><div class="article-metaline"><span class="article-meta-tag">標題</span><span class="article-meta-value">[好雷] 真愛趁現在-Old School什麼的最棒了！</span></div><div class="article-metaline"><span class="article-meta-tag">時間</span><span class="article-meta-value">Sat Apr 25 00:44:17 2020</span></div>
# 最近HBO在播，
# 真愛趁現在（Midnight Sun）
# 雖然台譯電影名很掉漆，
# 但覺得滿好看的，
# 推薦給大家。
#
#
# 防雷
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 最近幾年看了許多愛情電影，
# 大部分的套路都有跡可循，
# 這些電影中的愛情-除了愛情，
# 也總是夾雜很多很多，
# 好像感情世界再也不那麼純粹；
# 很久沒有看到一部電影，
# 這樣純純戀愛的電影。
# 就如同片中兩位男女主角，
# 他們所喜愛的Old School風格。
#
# 女主角因為從小患有罕見疾病，
# 不能照射到陽光，
# 只能在夜晚出來活動。
#
# 女主角人雖患病，
# 卻懷有著音樂的夢想，
# 夜晚在街頭走唱，
# 遇到出了意外，
# 無法再游泳男主角，
# 兩個人，
# 一個因為先天的疾病，
# 一個因為後天的遭遇，
# 惺惺相惜的一拍即合，
# 卻看起來那麼不偶然。
#
# 整部片給我的感覺，
# 就是很舒服，
# 不論是感情的主線，
# 還是親情友情的支線，
# 雖然從一開始知道女主角的罕見疾病，
# 我們就會一直擔心，，
# 下一段劇情將走向造化弄人，
# 但是這部電影是完全不狗血的，
# 看到女主角與每個人的互動，
# 會感覺溫暖從心中層層疊砌出來，
# 感動不言而喻，
# 心境隨著電影中人物起伏，
# 感覺內心有什麼遺忘了，
# 又好像要溢出來了。
#
#
# 故事結局如何我就不寫了，
# 真心推薦大家可以看看這部電影，
# 我覺得親眼觀影得到的，
# 一定會比我在這裡書寫的更多。
#
#
# 最後附上一首片尾曲，
# 天呀好好聽唷QQ
# 這年頭竟然還有這麼好看的愛情片，
# <a href="https://bit.ly/2S4wvyY" rel="nofollow" target="_blank">https://bit.ly/2S4wvyY</a>
#
#
# --
# <span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 114.137.2.38 (臺灣)
# </span><span class="f2">※ 文章網址: <a href="https://www.ptt.cc/bbs/movie/M.1587746659.A.C6B.html" rel="nofollow" target="_blank">https://www.ptt.cc/bbs/movie/M.1587746659.A.C6B.html</a>
# </span><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">Minazuki    </span><span class="f3 push-content">: 經典 太陽之歌 改編翻拍XDD</span><span class="push-ipdatetime"> 04/25 00:49
# </span></div><div class="push"><span class="f1 hl push-tag">→ </span><span class="f3 hl push-userid">plutox      </span><span class="f3 push-content">: 澤尻整個壞掉了</span><span class="push-ipdatetime"> 04/25 00:54
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">litann4     </span><span class="f3 push-content">: 這部後面哭爆</span><span class="push-ipdatetime"> 04/25 01:55
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">urchinchuang</span><span class="f3 push-content">: 推</span><span class="push-ipdatetime"> 04/25 12:21
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">dean3519    </span><span class="f3 push-content">: 推</span><span class="push-ipdatetime"> 04/25 19:12
# </span></div><div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">Tencc       </span><span class="f3 push-content">: 女二超正,比女主角正@@</span><span class="push-ipdatetime"> 04/25 20:05
# </span></div></div>

# %%
soup.select('div[id="main-content"]')[0].text.split('※ 發信站')[0]
# Out:
# '作者plutox (網路上的芳鄰)看板movie標題[好雷] 真愛趁現在-Old School什麼的最棒了！時間Sat Apr 25 00:44:17 2020\n最近HBO在播，\n真愛趁現在（Midnight Sun）\n雖然台譯電影名很掉漆，\n但覺得滿好看的，\n推薦給大家。\n\n\n防雷\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n最近幾年看了許多愛情電影，\n大部分的套路都有跡可循，\n這些電影中的愛情-除了愛情，\n也總是夾雜很多很多，\n好像感情世界再也不那麼純粹；\n很久沒有看到一部電影，\n這樣純純戀愛的電影。\n就如同片中兩位男女主角，\n他們所喜愛的Old School風格。\n\n女主角因為從小患有罕見疾病，\n不能照射到陽光，\n只能在夜晚出來活動。\n\n女主角人雖患病，\n卻懷有著音樂的夢想，\n夜晚在街頭走唱，\n遇到出了意外，\n無法再游泳男主角，\n兩個人，\n一個因為先天的疾病，\n一個因為後天的遭遇，\n惺惺相惜的一拍即合，\n卻看起來那麼不偶然。\n\n整部片給我的感覺，\n就是很舒服，\n不論是感情的主線，\n還是親情友情的支線，\n雖然從一開始知道女主角的罕見疾病，\n我們就會一直擔心，，\n下一段劇情將走向造化弄人，\n但是這部電影是完全不狗血的，\n看到女主角與每個人的互動，\n會感覺溫暖從心中層層疊砌出來，\n感動不言而喻，\n心境隨著電影中人物起伏，\n感覺內心有什麼遺忘了，\n又好像要溢出來了。\n\n\n故事結局如何我就不寫了，\n真心推薦大家可以看看這部電影，\n我覺得親眼觀影得到的，\n一定會比我在這裡書寫的更多。\n\n\n最後附上一首片尾曲，\n天呀好好聽唷QQ\n這年頭竟然還有這麼好看的愛情片，\nhttps://bit.ly/2S4wvyY\n\n\n--\n'
