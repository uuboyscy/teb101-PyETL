# %%
import requests
from bs4 import BeautifulSoup

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36'}

url = 'https://www.ptt.cc/bbs/Gossiping/index.html'

# %%
ss = requests.session()

ss.cookies['over18'] = '1'

res = ss.get(url, headers=headers)

# %%
print(res.text)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	<script async src='/cdn-cgi/bm/cv/2172558837/api.js'></script></head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# ...

# %%
import requests
from bs4 import BeautifulSoup

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36'}

url = 'https://www.ptt.cc/ask/over18?from=%2Fbbs%2FGossiping%2Findex.html'
ss = requests.session()

res = ss.get(url, headers=headers)
soup = BeautifulSoup(res.text, 'html.parser')

# %%
soup.select('form')
# Out:
# [<form action="/ask/over18" method="post">
#  <input name="from" type="hidden" value="/bbs/Gossiping/index.html"/>
#  <div class="over18-button-container">
#  <button class="btn-big" name="yes" type="submit" value="yes">我同意，我已年滿十八歲<br/><small>進入</small></button>
#  </div>
#  <div class="over18-button-container">
#  <button class="btn-big" name="no" type="submit" value="no">未滿十八歲或不同意本條款<br/><small>離開</small></button>
#  </div>
#  </form>]

# %%
over18_url = 'https://www.ptt.cc' + soup.select('form')[0]['action']
over18_url
# Out:
# 'https://www.ptt.cc/ask/over18'

# %%
soup.select('form')[0].select('input')
# Out:
# [<input name="from" type="hidden" value="/bbs/Gossiping/index.html"/>]

# %%
hid_key = soup.select('form')[0].select('input')[0]['name']
hid_key
# Out:
# 'from'

# %%
hid_value = soup.select('form')[0].select('input')[0]['value']
hid_value
# Out:
# '/bbs/Gossiping/index.html'

# %%
data = {}
data[hid_key] = hid_value

# %%
data['yes'] = 'yes'

# %%
ss.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='__cf_bm', value='ae80a8d6adbb70045ab0f84514c964eae67d24ff-1587884948-1800-AV+r+kh292beCpXczh2G50pSA/Jy5gT3U1VgznReFva+YtpyWIY61BYppubuWk6HOtpV9+UG6w+o19oBdp5Pwaw=', port=None, port_specified=False, domain='.ptt.cc', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=1587886748, discard=False, comment=None, comment_url=None, rest={'HttpOnly': None, 'SameSite': 'None'}, rfc2109=False), Cookie(version=0, name='__cfduid', value='d11a69d600111a6e81dcf0935036995071587884948', port=None, port_specified=False, domain='.ptt.cc', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=1590476948, discard=False, comment=None, comment_url=None, rest={'HttpOnly': None, 'SameSite': 'Lax'}, rfc2109=False)]>

# %%
ss.post(over18_url, headers=headers, data=data)
# Out:
# <Response [200]>

# %%
ss.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='__cf_bm', value='a67ac080dfaf4f48bb3269a4b6fdc11e964a1ef7-1587885443-1800-AUcq5zBJzR2GZdOOabVECiHUpZ+p+8+NOBtPD5qgCPHKeQyYK/a9lPbyTZqzlajuQmePK5VLe+pb1cpaVSI3zDY=', port=None, port_specified=False, domain='.ptt.cc', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=1587887243, discard=False, comment=None, comment_url=None, rest={'HttpOnly': None, 'SameSite': 'None'}, rfc2109=False), Cookie(version=0, name='__cfduid', value='d11a69d600111a6e81dcf0935036995071587884948', port=None, port_specified=False, domain='.ptt.cc', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=1590476948, discard=False, comment=None, comment_url=None, rest={'HttpOnly': None, 'SameSite': 'Lax'}, rfc2109=False), Cookie(version=0, name='over18', value='1', port=None, port_specified=False, domain='www.ptt.cc', domain_specified=False, domain_initial_dot=False, path='/', pa
# ...

# %%
url = 'https://www.ptt.cc/bbs/Gossiping/index.html'
res = ss.get(url, headers=headers)
print(res.text)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	<script async src='/cdn-cgi/bm/cv/2172558837/api.js'></script></head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# ...
